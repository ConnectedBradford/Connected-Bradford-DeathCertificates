# %%
from google.cloud import bigquery

# Initialize the BigQuery client
client = bigquery.Client()

# Specify the dataset and table where you want to load the data
dataset_id = 'CB_MYSPACE_PAA'
table_id = 'src_NEC_Deaths_reference_PostcodeGeography'  # Replace with your actual table name

# Define the schema for the table
schema = [
bigquery.SchemaField('DMIC_PostcodeGeographyKey', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Postcode_Sector', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Postcode_District', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Date_of_Introduction', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Date_of_Termination', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Grid_Ref_Easting', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Grid_Ref_Northing', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('County_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('County_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Local_Authority_Organisation_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Local_Authority_Organisation_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Local_Authority_District_Unitary_Authority_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Local_Authority_District_Unitary_Authority_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Electoral_Ward_or_Division_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Electoral_Ward_or_Division_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Postcode_Usertype', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Grid_Ref_Positional_Quality_Indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Country_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Country_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Strategic_Health_Authority_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Strategic_Health_Authority_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GOR_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('GOR_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Health_Authority_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Health_Authority_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Commissioning_Region_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Commissioning_Region_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Primary_Care_Organisation_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Primary_Care_Organisation_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr1991_Census_ED_Census_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('ED_Positional_Quality_Indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr1998_Ward_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2001_Census_Output_Area', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Area_Team_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Area_Team_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PAN_SHA_Country_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PAN_SHA_Country_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2001_Census_Urban_Rural_Indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('LSOA_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('LSOA_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MSOA_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('MSOA_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Cancer_Network_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Cancer_Network_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Strategic_Clinical_Network_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Strategic_Clinical_Network_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Pre_July_2006_SHA', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Old_PCT', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Old_IT_Cluster_Country', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Parliamentary_Constituency_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Parliamentary_Constituency_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Cancer_Registry_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Cancer_Registry_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Second_Wave', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2011_OA', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2011_LSOA_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2011_LSOA_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2011_MSOA_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2011_MSOA_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('PO_Box_NonGeographic_Indicator', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('yr2001_Census_Output_Area_Ind', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Scottish_Datazone', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Urban_Rural_Indicator_EandW', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Urban_Rural_Indicator_Scot', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Latitude_110m', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Longitude_110m', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Postcode_Country_Pseudo_Code', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('Postcode_Country_Pseudo_Name', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CareHomeAtPostcode', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CQC_CareHomes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('CQC_ServiceTypes', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DMIC_RECORD_VALID_DATE_FROM', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DMIC_RECORD_VALID_DATE_TO', 'STRING', mode='NULLABLE'),
bigquery.SchemaField('DMIC_RECORD_VALID_IS_LATEST', 'STRING', mode='NULLABLE')

]

# Define the configuration for the load job
load_config = bigquery.LoadJobConfig(
    autodetect=True,  # Automatically infer the schema from the data
    skip_leading_rows=2,  # Skip 2 leading rows
    field_delimiter="~",  # Specify the delimiter as pipe character
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,  # Append data to existing table
    schema=schema  # Add the schema definition
)
# Load the data from the specified URI (Google Cloud Storage path)
uri = 'gs://yhcr-prd-phm-bia-core-data-landing-bradford/src_NEC_Deaths_reference_PostcodeGeography.txt'
table_ref = client.dataset(dataset_id).table(table_id)
load_job = client.load_table_from_uri(uri, table_ref, job_config=load_config)

# Wait for the job to complete
load_job.result()

# Check if the job was successful
if load_job.state == 'DONE':
    print(f"Data loaded successfully into {dataset_id}.{table_id}")
else:
    print(f"Error loading data: {load_job.errors}")
# Out:
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /opt/conda/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Data loaded successfully into CB_MYSPACE_PAA.src_NEC_Deaths_reference_PostcodeGeography
